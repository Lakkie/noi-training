# %% [markdown]
# # 第一章 数与代数

# %% [markdown]
# ## 第一节 数的认识和运算

# %% [markdown]
# ### 一 整数

# %% [markdown]
# 考点1 整数的基本概念
#
# 十进制计数法
#
# 整数的数位顺序表
#
# 整数的读法
#
# 整数的写法

# %% [markdown]
# 考点2 整数的带余除法
#
# 整数除法的余数

# %%
考点3 整数的整除

因数或约数

奇数和偶数

# %%
考点4 质数和合数

0和1不是质数和合数，2是最小的质数，4是最小的合数

# %%
考点5 分解质因数

只针对合数

# %%
考点6 最大公因数和最小公倍数

几个数公有的最大因数是最大公因数

几个数公有的最小倍数是最小公倍数
