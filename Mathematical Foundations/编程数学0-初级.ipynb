# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image = mpimg.imread('m1.png')
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
image = mpimg.imread('m2.png')
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# # 1. 几何初步

# %% [markdown]
# ## 1.1 周长 Perimeter

# %% [markdown]
# 周长是封闭图形边界总长度。
# Total length of a closed shape's boundary.

# %% [markdown]
# ## 1.2 面积 Area

# %% [markdown]
# 面积是二维图形内部区域大小。
# Measure of a two-dimensional surface region.

# %% [markdown]
# ## 1.3 体积 Volume

# %% [markdown]
# 体积是三维物体占据的空间大小。
# Space occupied by a three-dimensional object.

# %% [markdown]
# ## 1.4 勾股定理

# %% [markdown]
# ## 1.5 平面直角坐标系

# %% [markdown]
# ## 1.6 两点之间的距离

# %% [markdown]
# # 2 数组

# %% [markdown]
# ## 2.1 一维数组

# %% [markdown]
# ## 2.2 二维数组

# %% [markdown]
# ## 2.3 多维数组
