# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image = mpimg.imread('m1.png')
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# # 1. 几何初步

# %% [markdown]
# ## 1.1 周长

# %% [markdown]
# 周长是一个封闭图形（平面图形）所有边界的总长度。

# %% [markdown]
# ## 1.2 面积
