# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image1 = mpimg.imread('m1.png')
image2 = mpimg.imread('m2.png')
plt.imshow(image1)
plt.imshow(image2)
plt.axis('off')
plt.show()
