# %% [markdown]
# # 5.1 初等数论

# %% [markdown]
# # 5.2 （C++）数组模拟高精度加法、减法、乘法、除法

# %% [markdown]
# # 5.3 单链表、双链表、循环链表

# %% [markdown]
# # 5.4 辗转相除法（也称欧几里得算法）

# %% [markdown]
# # 5.5 素数表的埃氏筛法和线性筛法

# %% [markdown]
# # 5.6 唯一分解定理

# %% [markdown]
# # 5.7 二分查找/二分答案（也称二分枚举法）

# %% [markdown]
# # 5.8 贪心算法

# %% [markdown]
# # 5.9 分治算法（归并排序和快速排序）

# %% [markdown]
# # 5.10 递归

# %% [markdown]
# # 5.11 算法复杂度的估算（含多项式、指数、对数复杂度）
