# %% [markdown]
# 2.1 计算机的存储与网络

# %% [markdown]
# 2.2 程序设计语言的特点

# %% [markdown]
# 2.3 流程图的概念与描述

# %% [markdown]
# 2.4 ASCII 编码

# %% [markdown]
# 2.5 数据类型的转换

# %% [markdown]
# 2.6 多层分支/循环结构

# %% [markdown]
# 2.7 常用数学函数（绝对值函数、平方根函数、max 函数、min 函数）
