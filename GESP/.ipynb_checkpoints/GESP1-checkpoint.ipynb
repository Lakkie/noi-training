# %% [markdown]
# 1.1 计算机基础与编程环境

# %% [markdown]
# 1.2 计算机历史

# %% [markdown]
# 1.3 变量的定义与使用

# %% [markdown]
# 1.4 基本数据类型（整型、浮点型、字符型、布尔型）

# %% [markdown]
# 1.5 控制语句结构（顺序、循环、选择）

# %% [markdown]
# 1.6 基本运算（算术运算、关系运算、逻辑运算）

# %% [markdown]
# 1.7 输入输出语句
