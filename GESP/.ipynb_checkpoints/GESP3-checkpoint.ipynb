# %% [markdown]
# 3.1 数据编码（原码、反码、补码）
# 3.2 进制转换（二进制、八进制、十进制、十六进制）
# 3.3 位运算（与（&）、或（|）、非（~）、异或（^）、左移（<<）、右移(>>)）
# 3.4 算法的概念与描述（自然语言描述、流程图描述、伪代码描述）
# 3.5 C++一维数组基本应用；Python 列表、字典、元组、集合的基本应用、内置函数以及列表解析的使用
# 3.6 字符串及其函数
# 3.7 算法：枚举法
# 3.8 算法：模拟法
