# %% [markdown]
# 6.1 树的定义，构造与遍历
# 6.2 哈夫曼树
# 6.3 完全二叉树
# 6.4 二叉排序树
# 6.5 哈夫曼编码
# 6.6 格雷编码
# 6.7 深度优先搜索算法
# 6.8 宽度优先搜索算法（也称广度优先搜索算法）
# 6.9 二叉树的搜索算法
# 6.10 简单动态规划（一维动态规划、简单背包问题）
# 6.11 面向对象的思想
# 6.12 类的创建
# 6.13 栈、队列、循环队列
