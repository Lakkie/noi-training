# %% [markdown]
# $A \alpha B \beta \Gamma \gamma \Delta \delta E \epsilon Z \zeta H \eta \Theta \theta I \iota K \kappa \Lambda \lambda M \mu N \nu \Xi \xi O \omicron \Pi \pi P \rho \Sigma \sigma T \tau Y \upsilon \Phi \phi X \chi \Psi \psi \Omega \omega Lp \ell_p$

# %% [markdown]
# $\varepsilon \vartheta \varrho \varsigma \varphi$
