# %% [markdown]
# 计算之魂
# ISBN: 9787115576170

# %% [markdown]
# # 引子 计算的本质-从机械到电子

# %% [markdown]
# ## 0.1　什么是计算机

# %% [markdown]
# ## 0.2　机械计算机、布尔代数和开关电路

# %% [markdown]
# ## 0.3　图灵机：计算的本质是机械运动

# %% [markdown]
# ## 0.4　人工智能的极限

# %% [markdown]
# # 第1章 毫厘千里之差-大 O 概念

# %% [markdown]
# ## 1.1　算法的规范化和量化度量

# %% [markdown]
# ## 1.2　大数和数量级的概念

# %% [markdown]
# ## 1.3　怎样寻找好的算法

# %% [markdown]
# ## 1.4　关于排序的讨论

# %% [markdown]
# # 第2章 逆向思考-从递推到递归

# %% [markdown]
# ## 2.1　递归：计算思维的核心

# %% [markdown]
# ## 2.2　遍历：递归思想的典型应用

# %% [markdown]
# ## 2.3　堆栈和队列：遍历的数据结构

# %% [markdown]
# ## 2.4　嵌套：自然语言的结构特征

# %% [markdown]
# # 第3章 万物皆编码-抽象与表示

# %% [markdown]
# ## 3.1　人和计算机对信息编码的差异

# %% [markdown]
# ## 3.2　分割黄金问题和小白鼠试验问题

# %% [markdown]
# ## 3.3　数据的表示、精度和范围

# %% [markdown]
# ## 3.4　非线性编码和增量编码（差分编码）

# %% [markdown]
# ## 3.5　哈夫曼编码

# %% [markdown]
# ## 3.6　矩阵的有效表示

# %% [markdown]
# # 第4章 智能的本质-分类与组合

# %% [markdown]
# ## 4.1　这是选择分类问题

# %% [markdown]
# ## 4.2　组织信息：集合与判定

# %% [markdown]
# ## 4.3　B 树、B* 树：数据库中的数据组织方式

# %% [markdown]
# ## 4.4　卡特兰数

# %% [markdown]
# # 第5章 工具与算法-图论及应用

# %% [markdown]
# ## 5.1　图的本质：点与线

# %% [markdown]
# ## 5.2　图的访问：遍历和连通性

# %% [markdown]
# ## 5.3　构建网络爬虫的工程问题

# %% [markdown]
# ## 5.4　动态规划：寻找短路径的有效方法

# %% [markdown]
# ## 5.5　流量：解决交通问题的方法

# %% [markdown]
# ## 5.6　配对：流量问题的扩展

# %% [markdown]
# # 第6章 化繁为简-分治思想及应用

# %% [markdown]
# ## 6.1　分治：从O(N2) 到O(NlogN)

# %% [markdown]
# ## 6.2　分割算法：快速排序和中值问题

# %% [markdown]
# ## 6.3　并行初探：矩阵相乘和 MapReduce

# %% [markdown]
# ## 6.4　从机器学习到深度学习：Google 大脑

# %% [markdown]
# # 第7章 权衡时空-理解存储

# %% [markdown]
# ## 7.1　访问：顺序 vs. 随机

# %% [markdown]
# ## 7.2　层次：容量 vs. 速度

# %% [markdown]
# ## 7.3　索引：地址 vs. 内容

# %% [markdown]
# # 第8章 并行与串行-流水线和分布式计算

# %% [markdown]
# ## 8.1　流水线：逻辑串行和物理并行

# %% [markdown]
# ## 8.2　摩尔定律的两条分水岭

# %% [markdown]
# ## 8.3　云计算揭密：GFS 和 MapReduce

# %% [markdown]
# # 第9章 状态与流程-等价性与因果关系

# %% [markdown]
# ## 9.1　从问题到状态

# %% [markdown]
# ## 9.2　等价性：抽象出状态的工具

# %% [markdown]
# ## 9.3　因果关系：建立状态之间的联系

# %% [markdown]
# # 第10章 确定与随机-概率算法及应用

# %% [markdown]
# ## 10.1　信息指纹：寓确定于随机之中

# %% [markdown]
# ## 10.2　随机性和量子通信

# %% [markdown]
# ## 10.3　置信度：成本与效果的平衡

# %% [markdown]
# # 第11章 理论与实战-典型难题精解

# %% [markdown]
# ## 11.1　长连续子序列问题

# %% [markdown]
# ## 11.2　区间合并问题

# %% [markdown]
# ## 11.3　12 球问题

# %% [markdown]
# ## 11.4　天际线问题

# %% [markdown]
# ## 11.5　长回文问题（Longest Palindrome Match）

# %% [markdown]
# ## 11.6　计算器问题

# %% [markdown]
# ## 11.7　如何产生搜索结果的摘要（Snippets Generation）

# %% [markdown]
# ## 11.8　寻找和等于k 的子数组问题
