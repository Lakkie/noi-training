# %% [markdown]
# Elementary Number Theory and Its Applications 初等数论及其应用（第7版）
# ISBN：9787111779797

# %% [markdown]
# What Is Number Theory?
# 何谓数论

# %% [markdown]
# Number theory is a core branch of pure mathematics focused on the properties of positive integers and related integer-based problems‌.
# 数论是纯数学的核心分支，专注于正整数的性质及相关基于整数的问题研究。

# %% [markdown]
# # 1 The Integers 整数

# %% [markdown]
# ## 1.1 Numbers and Sequences 数和序列

# %% [markdown]
# ## 1.2 Sums and Products 和与积

# %% [markdown]
# ## 1.3 Mathematical Induction 数学归纳法

# %% [markdown]
# ## 1.4 The Fibonacci Numbers 斐波那契数

# %% [markdown]
# ## 1.5 Divisibility 整除性

# %% [markdown]
# # 2 Integer Representations and Operations 整数的表示法和运算

# %% [markdown]
# ## 2.1 Representations of Integers 整数的表示法

# %% [markdown]
# ## 2.2 Computer Operations with Integers 整数的计算机运算

# %% [markdown]
# ## 2.3 Complexity of Integer Operations 整数运算的复杂度

# %% [markdown]
# # 3 Greatest Common Divisors 最大公因子

# %% [markdown]
# ## 3.1 Greatest Common Divisors and Their Properties 最大公因子及其性质

# %% [markdown]
# ## 3.2 The Euclidean Algorithm 欧几里得算法

# %% [markdown]
# ## 3.3 Linear Diophantine Equations 线性丢番图方程

# %% [markdown]
# # 4 Prime Numbers 素数

# %% [markdown]
# ## 4.1 Introduction to Prime Numbers 素数概述

# %% [markdown]
# ## 4.2 The Distribution of Primes 素数的分布

# %% [markdown]
# ## 4.3 The Fundamental Theorem of Arithmetic 算术基本定理

# %% [markdown]
# ## 4.4 Factorization Methods and the Fermat Numbers 因子分解方法和费马数

# %% [markdown]
# # 5 Congruences 同余

# %% [markdown]
# ## 5.1 Introduction to Congruences 同余概述

# %% [markdown]
# ## 5.2 Linear Congruences 线性同余方程

# %% [markdown]
# ## 5.3 The Chinese Remainder Theorem 中国剩余定理

# %% [markdown]
# ## 5.4 Polynomial Congruences 求解多项式同余方程

# %% [markdown]
# ## 5.5 Systems of Linear Congruences 线性同余方程组

# %% [markdown]
# ## 5.6 Factoring Using the Pollard Rho Method 利用波拉德ρ方法分解整数

# %% [markdown]
# # 6 Applications of Congruences 同余的应用

# %% [markdown]
# ## 6.1 Divisibility Tests 整除性检验

# %% [markdown]
# ## 6.2 The Perpetual Calendar 万年历

# %% [markdown]
# ## 6.3 Round-Robin Tournaments 循环赛赛程

# %% [markdown]
# ## 6.4 Hashing Functions 散列函数

# %% [markdown]
# ## 6.5 Check Digits 校验位

# %% [markdown]
# # 7 Some Special Congruences 特殊的同余式

# %% [markdown]
# ## 7.1 Wilson‘s Theorem and Fermat’s Little Theorem 威尔逊定理和费马小定理

# %% [markdown]
# ## 7.2 Pseudoprimes 伪素数

# %% [markdown]
# ## 7.3 Euler’s Theorem 欧拉定理

# %% [markdown]
# # 8 Arithmetic Functions 算术函数

# %% [markdown]
# ## 8.1 The Euler Phi-Function 欧拉φ函数

# %% [markdown]
# ## 8.2 The Sum and Number of Divisors 因子和与因子个数

# %% [markdown]
# ## 8.3 Perfect Numbers and Mersenne Primes 完全数和梅森素数

# %% [markdown]
# ## 8.4 Mobius Inversion 莫比乌斯反演

# %% [markdown]
# ## 8.5 Partitions 拆分

# %% [markdown]
# # 9 Cryptology 密码学

# %% [markdown]
# ## 9.1 Character Ciphers 字符密码

# %% [markdown]
# ## 9.2 Block and Stream Ciphers 分组密码和流密码

# %% [markdown]
# ## 9.3 Exponentiation Ciphers 指数密码

# %% [markdown]
# ## 9.4 Public Key Cryptography 公钥密码学

# %% [markdown]
# ## 9.5 Cryptographic Protocols and Applications 密码协议及应用

# %% [markdown]
# # 10 Primitive Roots 原根

# %% [markdown]
# ## 10.1 The Order of an Integer and Primitive Roots 整数的阶和原根

# %% [markdown]
# ## 10.2 Primitive Roots for Primes 素数的原根

# %% [markdown]
# ## 10.3 The Existence of Primitive Roots 原根的存在性

# %% [markdown]
# ## 10.4 Discrete Logarithms and Index Arithmetic 离散对数和指数的算术

# %% [markdown]
# ## 10.5 Primality Tests Using Orders of Integers and Primitive Roots 用整数的阶和原根进行素性检验

# %% [markdown]
# ## 10.6 Universal Exponents 通用指数

# %% [markdown]
# # 11 Applications of the Order of an Integer 整数阶的应用

# %% [markdown]
# ## 11.1 Pseudorandom Numbers 伪随机数

# %% [markdown]
# ## 11.2 The ElGamal Cryptosystem 埃尔伽莫密码系统

# %% [markdown]
# ## 11.3 An Application to the Splicing of Telephone Cables 电话线缆绞接中的应用

# %% [markdown]
# # 12 Quadratic Residues 二次剩余

# %% [markdown]
# ## 12.1 Quadratic Residues and Nonresidues 二次剩余与二次非剩余

# %% [markdown]
# ## 12.2 The Law of Quadratic Reciprocity 二次互反律

# %% [markdown]
# ## 12.3 The Jacobi Symbol 雅可比符号

# %% [markdown]
# ## 12.4 Euler Pseudoprimes 欧拉伪素数

# %% [markdown]
# ## 12.5 Zero-Knowledge Proofs 零知识证明

# %% [markdown]
# # 13 Decimal Fractions and Continued Fractions 十进制分数与连分数

# %% [markdown]
# ## 13.1 Decimal Fractions 十进制分数

# %% [markdown]
# ## 13.2 Finite Continued Fractions 有限连分数

# %% [markdown]
# ## 13.3 Infinite Continued Fractions 无限连分数

# %% [markdown]
# ## 13.4 Periodic Continued Fractions 循环连分数

# %% [markdown]
# ## 13.5 Factoring Using Continued Fractions 用连分数进行因子分解

# %% [markdown]
# # 14 Nonlinear Diophantine Equations and Elliptic Curves 非线性丢番图方程与椭圆曲线

# %% [markdown]
# ## 14.1 Pythagorean Triples 毕达哥拉斯三元组

# %% [markdown]
# ## 14.2 Fermat’s Last Theorem 费马大定理

# %% [markdown]
# ## 14.3 Sums of Squares 平方和

# %% [markdown]
# ## 14.4 Pell’s Equation 佩尔方程

# %% [markdown]
# ## 14.5 Congruent Numbers and Elliptic Curves 同余数和椭圆曲线

# %% [markdown]
# ## 14.6 Elliptic Curves Modulo Primes 模素数椭圆曲线

# %% [markdown]
# ## 14.7 Applications of Elliptic Curves 椭圆曲线的应用

# %% [markdown]
# # 15 The Gaussian Integers 高斯整数

# %% [markdown]
# ## 15.1 Gaussian Integers and Gaussian Primes 高斯整数和高斯素数

# %% [markdown]
# ## 15.2 Greatest Common Divisors and Unique Factorization 最大公因子和唯一因子分解

# %% [markdown]
# ## 15.3 Gaussian Integers and Sums of Squares 高斯整数与平方和

# %% [markdown]
# # Appendix A Axioms for the Set of Integers 整数集公理

# %% [markdown]
# # Appendix B Binomial Coefficients 二项式系数

# %% [markdown]
# # Appendix C Using Maple, Mathe-matica, and SageMath for Number Theory Maple、Mathematica和SageMath在数论中的应用

# %% [markdown]
# ## C.1 Using Maple for Number Theory Maple在数论中的应用

# %% [markdown]
# ## C.2 Using Mathematica for Number Theory Mathematica在数论中的应用

# %% [markdown]
# ## C.3 Using SageMath for Number Theory SageMath在数论中的应用

# %% [markdown]
# # Appendix D Number Theory Web Links 有关数论的网站

# %% [markdown]
# # Appendix E Tables 表

# %% [markdown]
# # Appendix F Inventory of Unsolved Problems 未解决问题精选
